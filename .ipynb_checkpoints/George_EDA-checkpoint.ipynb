# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Name                   2
# Platform               0
# Year_of_Release      269
# Genre                  2
# Publisher             54
# NA_Sales               0
# EU_Sales               0
# JP_Sales               0
# Other_Sales            0
# Global_Sales           0
# Critic_Score        8582
# Critic_Count        8582
# User_Score          9129
# User_Count          9129
# Developer           6623
# Rating              6769
# Hit                14662
# dtype: int64

# %%
df_no_critics = df[df['Critic_Score'].isna()]
df_no_critics[df_no_critics['Year_of_Release'] > 2006].head(50)
# Out:
#                                                   Name Platform  \
# 27                         Pokemon Black/Pokemon White       DS
# 31                           Call of Duty: Black Ops 3      PS4
# 33                                 Pokemon X/Pokemon Y      3DS
# 46                Pokemon HeartGold/Pokemon SoulSilver       DS
# 47           Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 72                                           Minecraft     X360
# 83                     Pokemon Black 2/Pokemon White 2       DS
# 86                  Mario & Sonic at the Olympic Games      Wii
# 87                        Star Wars Battlefront (2015)      PS4
# 96                 Super Smash Bros. for Wii U and 3DS      3DS
# 99                           Call of Duty: Black Ops 3     XOne
# 108                                   Pokemon Sun/Moon      3DS
# 119                                      Zumba Fitness      Wii
# 122                                            FIFA 12      PS3
# ...

# %%
df.groupby('Name').sum()
df['Name'].value_counts()
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
df[df['Name'] == 'Need for Speed: Most Wanted']
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 253    Need for Speed: Most Wanted      PS2           2005.0  Racing
# 523    Need for Speed: Most Wanted      PS3           2012.0  Racing
# 1190   Need for Speed: Most Wanted     X360           2012.0  Racing
# 1591   Need for Speed: Most Wanted     X360           2005.0  Racing
# 1998   Need for Speed: Most Wanted       XB           2005.0  Racing
# 2048   Need for Speed: Most Wanted      PSV           2012.0  Racing
# 3581   Need for Speed: Most Wanted       GC           2005.0  Racing
# 5973   Need for Speed: Most Wanted       PC           2005.0  Racing
# 6274   Need for Speed: Most Wanted     WiiU           2013.0  Racing
# 6411   Need for Speed: Most Wanted       DS           2005.0  Racing
# 6474   Need for Speed: Most Wanted      GBA           2005.0  Racing
# 11716  Need for Speed: Most Wanted       PC           2012.0  Racing
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df['Hit'] = 0

# %%
df.loc[(df.Global_Sales > 1), 'Hit'] = 1
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df_lazy = df.dropna()
df_lazy
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
X = df_lazy.drop('Hit', axis=1)
y = df_lazy['Hit']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)

# %%
numeric = ['Critic_Score', 'User_Score']

X_train_numeric = X_train[numeric]
X_test_numeric = X_test[numeric]
y_train.value_counts()
# Out:
# 0    4151
# 1     967
# Name: Hit, dtype: int64

# %%
baseline_model = LogisticRegression()

baseline_model.fit(X_train_numeric, y_train)

baseline_model.score(X_train_numeric, y_train)
# Out:
# 0.8214146150840171

# %%
baseline_model.score(X_test_numeric, y_test)
# Out:
# 0.8201523140011716
